# %%
# -*- coding: utf-8 -*-
"""
TP_0

@author: Wesley
"""
# Importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

dataset = pd.read_csv('kmean-course.csv')
dataset = dataset.astype(float)

initial_centroids =  np.array([
    [3, 4],  # First centroid
    [4.5, 5],  # Second centroid
])

classifier = KMeans(n_clusters=2, init=initial_centroids, n_init=1)

# Classify elements in the dataset
classifier.fit(dataset)

# Get the classification label
labels = classifier.labels_

fig = plt.figure(figsize=(10, 8))

fig_title = "Dataset View"

ax = fig.add_subplot(2, 2, 2)

ax.scatter(dataset["X"], dataset["Y"], c=labels.astype(float), edgecolor="k")

ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
ax.set_xlabel("X composante")
ax.set_ylabel("Y composante")
ax.set_title(fig_title)

plt.show()
